# %%
from HMM import *
from our_utilities import *

import os
import numpy as np
from IPython.display import HTML

from HMM import unsupervised_HMM
from HMM_helper import (
    text_to_wordcloud,
    states_to_wordclouds,
    parse_observations,
    sample_sentence,
    visualize_sparsities,
    animate_emission
)

# %%
hmmfiles = [ './HMM_4_1000_08180925.txt','./HMM_8_1000_08185921.txt','./HMM_12_1000_08202040.txt','./HMM_16_1000_08215927.txt','./HMM_32_1000_09101554.txt' ]  #sys.argv[1:]
sonnets, word2syll, word2index, index2word = loadsonnets()
HMMs = []
for hmmfile in hmmfiles:
#     print(hmmfile)
    HMMs.append(readHMM(hmmfile))

# %%
print('4 hidden states')
wordclouds = states_to_wordclouds(HMMs[0],word2index)
# Out:
# 4 hidden states

# %%
print('8 hidden states')
wordclouds = states_to_wordclouds(HMMs[1],word2index)
# Out:
# 8 hidden states

# %%
print('12 hidden states')
wordclouds = states_to_wordclouds(HMMs[2],word2index)
# Out:
# 12 hidden states

# %%
print('16 hidden states')
wordclouds = states_to_wordclouds(HMMs[3],word2index)
# Out:
# 16 hidden states

# %%
print('32 hidden states')
wordclouds = states_to_wordclouds(HMMs[4],word2index)
# Out:
# 32 hidden states
